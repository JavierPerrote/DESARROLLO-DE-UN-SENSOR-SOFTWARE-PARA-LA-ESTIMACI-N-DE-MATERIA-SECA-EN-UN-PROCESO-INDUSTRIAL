# %% [markdown]
# <a href="https://colab.research.google.com/github/JavierPerrote/DESARROLLO-DE-UN-SENSOR-SOFTWARE-PARA-LA-ESTIMACION-DE-MATERIA-SECA-EN-UN-PROCESO-INDUSTRIAL/blob/main/BoxplotFiltro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import pandas as pd
from torch import nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from IPython import display
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import math as math
import scipy.signal
import re
import seaborn as sns
from sklearn.metrics import mean_squared_error

# %%
dataFile = pd.read_csv('sensor.csv')

# %% [markdown]
# GENERAMOS EL FILTRO

# %%
# Primero generamos el filtro
dataFiltered = dataFile.copy()
for index,column in enumerate(dataFile.columns):


    if (column == 'Output'):
        b, a = scipy.signal.butter(2, 0.007)
        dataFiltered[column] = scipy.signal.filtfilt(b, a, dataFile[column], axis=0,padlen=100 )


    if re.match(r'^[pP]_va[hp]', column):
        b, a = scipy.signal.butter(2, 0.003)
        dataFiltered[column] = scipy.signal.filtfilt(b, a, dataFile[column], axis=0,padlen=100 )


    if (column.startswith('T_')):
        b, a = scipy.signal.butter(2, 0.005)
        dataFiltered[column] = scipy.signal.filtfilt(b, a, dataFile[column], axis=0,padlen=100 )


    if re.match(r'^e._T', column):
        b, a = scipy.signal.butter(2, 0.005)
        dataFiltered[column] = scipy.signal.filtfilt(b, a, dataFile[column], axis=0,padlen=100 )

    if (column.startswith('W_')):
        b, a = scipy.signal.butter(2, 0.005)
        dataFiltered[column] = scipy.signal.filtfilt(b, a, dataFile[column], axis=0,padlen=100 )

# %% [markdown]
# PRESIONES DEL VAPOR

# %%
# presiones
data = dataFiltered.loc[:,['P_vah_e1','P_vah_e2','P_vah_e3','P_vah_e4','P_vah_e5','P_vah_e6','p_vap_cald']]

nRowsG = math.ceil(len(data.columns) /2)
ncolumnsG = 2
plt.rcParams['figure.figsize'] = [20, 15]
plt.figure()
fig, axs = plt.subplots(nRowsG, ncolumnsG)
fig.tight_layout(pad=3.0)

for index,column in enumerate(data.columns):
    boxplot = axs[index // ncolumnsG, index % ncolumnsG].boxplot(data[column], vert=False, whis=3)
    axs[index // ncolumnsG, index % ncolumnsG].set_title(column)
    outliers = boxplot["fliers"][0].get_data()[0]
    total = len(data[column])
    outliers_percentage = len(outliers) / total * 100
    print(f"Porcentaje de valores atípicos en {column}: {outliers_percentage:.2f}%")
# Out:
# Porcentaje de valores atípicos en P_vah_e1: 0.00%
# Porcentaje de valores atípicos en P_vah_e2: 0.00%
# Porcentaje de valores atípicos en P_vah_e3: 0.00%
# Porcentaje de valores atípicos en P_vah_e4: 0.00%
# Porcentaje de valores atípicos en P_vah_e5: 0.00%
# Porcentaje de valores atípicos en P_vah_e6: 0.00%
# Porcentaje de valores atípicos en p_vap_cald: 0.00%

# %% [markdown]
# TEMPERATURAS DEL VAPOR

# %%
# presiones

data = dataFiltered.loc[:,['T_vah_e1', 'T_vah_e2', 'T_vah_e3',
       'T_vah_e4', 'T_vah_e5', 'T_vah_e6', 'T_vap_cald']]

nRowsG = math.ceil(len(data.columns) /2)
ncolumnsG = 2
plt.rcParams['figure.figsize'] = [20, 15]
plt.figure()
fig, axs = plt.subplots(nRowsG, ncolumnsG)
fig.tight_layout(pad=3.0)

for index,column in enumerate(data.columns):
    boxplot = axs[index // ncolumnsG, index % ncolumnsG].boxplot(data[column], vert=False, whis=3)
    axs[index // ncolumnsG, index % ncolumnsG].set_title(column)
    outliers = boxplot["fliers"][0].get_data()[0]
    total = len(data[column])
    outliers_percentage = len(outliers) / total * 100
    print(f"Porcentaje de valores atípicos en {column}: {outliers_percentage:.2f}%")
# Out:
# Porcentaje de valores atípicos en T_vah_e1: 0.00%
# Porcentaje de valores atípicos en T_vah_e2: 0.00%
# Porcentaje de valores atípicos en T_vah_e3: 0.00%
# Porcentaje de valores atípicos en T_vah_e4: 0.00%
# Porcentaje de valores atípicos en T_vah_e5: 0.00%
# Porcentaje de valores atípicos en T_vah_e6: 0.00%
# Porcentaje de valores atípicos en T_vap_cald: 0.00%

# %% [markdown]
# TEMPERATURAS DEL JUGO

# %%
# presiones
data =  dataFiltered.loc[:,['T_ent_e1','e1_T_jugo_salida',
'e2_T_jugo_salida', 'e3_T_jugo_salida', 'e4_T_jugo_salida',
'e5_T_jugo_salida', 'e6_T_jugo_salida']]

nRowsG = math.ceil(len(data.columns) /2)
ncolumnsG = 2
plt.rcParams['figure.figsize'] = [20, 15]
plt.figure()
fig, axs = plt.subplots(nRowsG, ncolumnsG)
fig.tight_layout(pad=3.0)

for index,column in enumerate(data.columns):
    boxplot = axs[index // ncolumnsG, index % ncolumnsG].boxplot(data[column], vert=False, whis=3)
    axs[index // ncolumnsG, index % ncolumnsG].set_title(column)
    outliers = boxplot["fliers"][0].get_data()[0]
    total = len(data[column])
    outliers_percentage = len(outliers) / total * 100
    print(f"Porcentaje de valores atípicos en {column}: {outliers_percentage:.2f}%")
# Out:
# Porcentaje de valores atípicos en T_ent_e1: 0.00%
# Porcentaje de valores atípicos en e1_T_jugo_salida: 0.00%
# Porcentaje de valores atípicos en e2_T_jugo_salida: 0.00%
# Porcentaje de valores atípicos en e3_T_jugo_salida: 0.00%
# Porcentaje de valores atípicos en e4_T_jugo_salida: 0.00%
# Porcentaje de valores atípicos en e5_T_jugo_salida: 0.00%
# Porcentaje de valores atípicos en e6_T_jugo_salida: 0.00%

# %% [markdown]
# TEMPERATURA EN LOS CAMBIADORES

# %%
# presiones
data = dataFiltered.loc[:,['T_entrada_R10', 'T_entrada_R13',
       'T_entrada_R14', 'T_entrada_R3', 'T_entrada_R3B', 'T_entrada_R8',
       'T_entrada_R9', 'T_jugo_anteevap']]

nRowsG = math.ceil(len(data.columns) /2)
ncolumnsG = 2
plt.rcParams['figure.figsize'] = [20, 15]
plt.figure()
fig, axs = plt.subplots(nRowsG, ncolumnsG)
fig.tight_layout(pad=3.0)

for index,column in enumerate(data.columns):
    boxplot = axs[index // ncolumnsG, index % ncolumnsG].boxplot(data[column], vert=False, whis=3)
    axs[index // ncolumnsG, index % ncolumnsG].set_title(column)
    outliers = boxplot["fliers"][0].get_data()[0]
    total = len(data[column])
    outliers_percentage = len(outliers) / total * 100
    print(f"Porcentaje de valores atípicos en {column}: {outliers_percentage:.2f}%")
# Out:
# Porcentaje de valores atípicos en T_entrada_R10: 5.19%
# Porcentaje de valores atípicos en T_entrada_R13: 0.00%
# Porcentaje de valores atípicos en T_entrada_R14: 0.00%
# Porcentaje de valores atípicos en T_entrada_R3: 0.00%
# Porcentaje de valores atípicos en T_entrada_R3B: 0.00%
# Porcentaje de valores atípicos en T_entrada_R8: 0.00%
# Porcentaje de valores atípicos en T_entrada_R9: 0.00%
# Porcentaje de valores atípicos en T_jugo_anteevap: 5.19%

# %%
# presiones
data = dataFiltered.loc[:,[ 'T_salida_R10', 'T_salida_R11',
       'T_salida_R12', 'T_salida_R3', 'T_salida_R3A', 'T_salida_R3B']]

nRowsG = math.ceil(len(data.columns) /2)
ncolumnsG = 2
plt.rcParams['figure.figsize'] = [20, 15]
plt.figure()
fig, axs = plt.subplots(nRowsG, ncolumnsG)
fig.tight_layout(pad=3.0)

for index,column in enumerate(data.columns):
    boxplot = axs[index // ncolumnsG, index % ncolumnsG].boxplot(data[column], vert=False, whis=3)
    axs[index // ncolumnsG, index % ncolumnsG].set_title(column)
    outliers = boxplot["fliers"][0].get_data()[0]
    total = len(data[column])
    outliers_percentage = len(outliers) / total * 100
    print(f"Porcentaje de valores atípicos en {column}: {outliers_percentage:.2f}%")
# Out:
# Porcentaje de valores atípicos en T_salida_R10: 3.38%
# Porcentaje de valores atípicos en T_salida_R11: 0.00%
# Porcentaje de valores atípicos en T_salida_R12: 0.00%
# Porcentaje de valores atípicos en T_salida_R3: 0.00%
# Porcentaje de valores atípicos en T_salida_R3A: 0.00%
# Porcentaje de valores atípicos en T_salida_R3B: 0.00%

# %%
# presiones
data = dataFiltered.loc[:,[
       'T_salida_R4', 'T_salida_R5', 'T_salida_R6', 'T_salida_R7',
       'T_salida_R8', 'T_salida_R9']]

nRowsG = math.ceil(len(data.columns) /2)
ncolumnsG = 2
plt.rcParams['figure.figsize'] = [20, 15]
plt.figure()
fig, axs = plt.subplots(nRowsG, ncolumnsG)
fig.tight_layout(pad=3.0)

for index,column in enumerate(data.columns):
    boxplot = axs[index // ncolumnsG, index % ncolumnsG].boxplot(data[column], vert=False, whis=3)
    axs[index // ncolumnsG, index % ncolumnsG].set_title(column)
    outliers = boxplot["fliers"][0].get_data()[0]
    total = len(data[column])
    outliers_percentage = len(outliers) / total * 100
    print(f"Porcentaje de valores atípicos en {column}: {outliers_percentage:.2f}%")
# Out:
# Porcentaje de valores atípicos en T_salida_R4: 0.00%
# Porcentaje de valores atípicos en T_salida_R5: 0.00%
# Porcentaje de valores atípicos en T_salida_R6: 0.00%
# Porcentaje de valores atípicos en T_salida_R7: 0.00%
# Porcentaje de valores atípicos en T_salida_R8: 0.00%
# Porcentaje de valores atípicos en T_salida_R9: 0.00%

# %% [markdown]
# FLUJO MASICO

# %%
# presiones
data =  dataFiltered.loc[:,['W_jugo_R10',
       'W_jugo_R3', 'W_jugo_R3B', 'W_jugo_R4', 'W_jugo_R8', 'W_jugo_R9',
       'W_jugo_anteevap', 'W_jugo_salida_e6', 'W_vap_cald']]

nRowsG = math.ceil(len(data.columns) /2)
ncolumnsG = 2
plt.rcParams['figure.figsize'] = [20, 15]
plt.figure()
fig, axs = plt.subplots(nRowsG, ncolumnsG)
fig.tight_layout(pad=3.0)

for index,column in enumerate(data.columns):
    boxplot = axs[index // ncolumnsG, index % ncolumnsG].boxplot(data[column], vert=False, whis=3)
    axs[index // ncolumnsG, index % ncolumnsG].set_title(column)
    outliers = boxplot["fliers"][0].get_data()[0]
    total = len(data[column])
    outliers_percentage = len(outliers) / total * 100
    print(f"Porcentaje de valores atípicos en {column}: {outliers_percentage:.2f}%")
# Out:
# Porcentaje de valores atípicos en W_jugo_R10: 0.00%
# Porcentaje de valores atípicos en W_jugo_R3: 0.00%
# Porcentaje de valores atípicos en W_jugo_R3B: 0.00%
# Porcentaje de valores atípicos en W_jugo_R4: 0.00%
# Porcentaje de valores atípicos en W_jugo_R8: 0.00%
# Porcentaje de valores atípicos en W_jugo_R9: 0.00%
# Porcentaje de valores atípicos en W_jugo_anteevap: 0.00%
# Porcentaje de valores atípicos en W_jugo_salida_e6: 0.00%
# Porcentaje de valores atípicos en W_vap_cald: 0.00%

# %% [markdown]
# EJEMPLO PARA FIGURA

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generar datos aleatorios
np.random.seed(123)
datos = np.concatenate([np.random.normal(0, 1, 50), np.random.normal(5, 1, 3), np.random.normal(-5, 1, 2)])

# Crear el boxplot
fig, ax = plt.subplots()
ax.boxplot(datos, vert=False)

# Reducir la escala del eje y
ax.set_ylim(0.6, 1.4)

# Ajustar la distancia entre el gráfico y los ejes
plt.subplots_adjust(bottom=0.6)

# Mostrar el boxplot
plt.show()
